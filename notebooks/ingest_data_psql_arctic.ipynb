# %% [markdown]
# # Imports

# %%
import arcticdb as adb
from pathlib import Path
import polars as pl
import pandas as pd, numpy as np
from dotenv import find_dotenv, dotenv_values
from datetime import datetime
from tqdm.notebook import tqdm

from crypto_trading.arctic import ArcticHandler

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Config / Params

# %% [markdown]
# ## Credentials

# %%
config = dotenv_values(find_dotenv())
user = config.get('USERNAME_PG')
password = config.get('PASSWORD_PG')

# %% [markdown]
# ## Database Connection

# %%
uri = f"postgresql://{user}:{password}@localhost:5432/crypto_data"

# %% [markdown]
# # Initiate Data Store

# %% [markdown]
# ## Create db

# %%
db_name = 'crypto_trading'
arctic_handler = ArcticHandler(db_name=db_name)

# %%
arctic_handler.arctic_db.list_libraries()
# Out:
# ['ohlc_1m']

# %%
lib_name = 'ohlc_1m'
arctic_handler.set_lib(lib_name=lib_name)
lib_ohlc_1m = arctic_handler.get_lib(lib_name)

# %% [markdown]
# # Ingest Data

# %% [markdown]
# ## Get Existing Symbol Info

# %%
query_symbol_info_mv = """
    SELECT
        symbol,
        last_datetime
    FROM perps_last_datetime
    WHERE 
        exchange = 'binance'
        AND symbol NOT IN ('ETHUSDT', 'BTCUSDT', 'SOLUSDT', 'BNBUSDT')
"""
df_symbol_info = pl.read_database_uri(query=query_symbol_info_mv, uri=uri)

# %%
list(df_symbol_info.filter(~df_symbol_info["symbol"].isin(['ETHUSDT', 'BTCUSDT', 'SOLUSDT', 'BNBUSDT']))['symbol'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 list(df_symbol_info.filter(~df_symbol_info["symbol"].isin(['ETHUSDT', 'BTCUSDT', 'SOLUSDT', 'BNBUSDT']))['symbol'])
#
# AttributeError: 'Series' object has no attribute 'isin'

# %% [markdown]
# ## Pull in some data from postgres

# %%
# symbols = ['ETHUSDT', 'BNBUSDT']
symbols = list(df_symbol_info['symbol'])

# %% [raw]
# exchange_name = 'binance'
#
# for symbol in tqdm(symbols):
#     print(symbol)
#     symbol_string = f'{exchange_name}_{symbol}'
#
#     print(f'{datetime.utcnow().strftime("%H:%M:%S")} - Getting data from postgres')
#     query_ohlc_data = query_test = f"""
#         SELECT *
#         FROM ohlc_1m_swaps_test
#         WHERE
#             symbol = '{symbol}'
#     """
#     df_ohlc_data = (
#         pl.read_database_uri(query=query_ohlc_data, uri=uri)
#         .to_pandas()
#         .set_index('datetime')
#         .sort_index()
#     )
#     metadata = {
#         'last_datetime':df_ohlc_data.index[-1]
#     }
#     print(f'{datetime.utcnow().strftime("%H:%M:%S")} - writing data to arctic')
#     lib_ohlc_1m.write(symbol=symbol_string, data=df_ohlc_data, metadata=metadata)
#     print('='*20)

# %%
symbols = [raw_symbol.split('_')[1] for raw_symbol in lib_ohlc_1m.list_symbols()]

{item.symbol.split('_')[1]:item.metadata.get('last_datetime') for item in lib_ohlc_1m.read_metadata_batch(symbols=lib_ohlc_1m.list_symbols())}
# Out:
# {'USDCUSDT': Timestamp('2024-06-12 20:34:00'),
#  'WAVESUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000SATSUSDT': Timestamp('2024-06-12 20:31:00'),
#  'STORJUSDT': Timestamp('2024-06-12 20:33:00'),
#  'NEOUSDC': Timestamp('2024-06-12 20:33:00'),
#  'ARKUSDT': Timestamp('2024-06-12 20:31:00'),
#  'LUNABUSD': Timestamp('2022-05-13 01:35:00'),
#  'NTRNUSDT': Timestamp('2024-06-12 20:33:00'),
#  'WIFUSDT': Timestamp('2024-06-12 20:34:00'),
#  'DGBUSDT': Timestamp('2024-06-11 23:36:00'),
#  'DOTECOUSDT': Timestamp('2021-02-19 09:37:00'),
#  'ROSEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'MOVRUSDT': Timestamp('2024-06-12 20:33:00'),
#  'TIAUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ICPBUSD': Timestamp('2023-03-22 09:28:00'),
#  'ALTUSDT': Timestamp('2024-06-12 20:31:00'),
#  'MINAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'DODOBUSD': Timestamp('2023-12-19 09:37:00'),
#  '1000XECUSDT': Timestamp('2024-06-12 20:31:00'),
#  'FTMUSDT': Timestamp('2024-06-12 20:32:00'),
#  'IOTAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'YFIIUSDT': Timestamp('2022-04-12 09:02:00'),
#  'DUSKUSDT': Timestamp('2024-06-12 20:32:00'),
#  'RIFUSDT': Timestamp('2024-06-12 20:33:00'),
#  'IMXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BELUSDT': Timestamp('2024-06-12 20:31:00'),
#  'PIXELUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ARPAUSDT': Timestamp('2024-06-12 20:31:00'),
#  'CYBERUSDT': Timestamp('2024-06-12 20:32:00'),
#  'AMBBUSD': Timestamp('2023-12-19 09:31:00'),
#  'ACEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'BLUEBIRDUSDT': Timestamp('2024-05-28 07:05:00'),
#  'THETAUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ETHFIUSDC': Timestamp('2024-06-12 20:32:00'),
#  'ANCBUSD': Timestamp('2023-12-19 09:32:00'),
#  'BTTUSDT': Timestamp('2022-01-26 11:34:00'),
#  'ALPHAUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ETHUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BTCSTUSDT': Timestamp('2024-06-11 22:15:00'),
#  'NUUSDT': Timestamp('2022-02-15 02:03:00'),
#  'COMPUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ARUSDT': Timestamp('2024-06-12 20:31:00'),
#  'RUNEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BTCDOMUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ETHUSDC': Timestamp('2024-06-12 20:32:00'),
#  'LEVERBUSD': Timestamp('2023-12-19 09:45:00'),
#  'HBARUSDT': Timestamp('2024-06-12 20:32:00'),
#  'LITUSDT': Timestamp('2024-06-12 20:33:00'),
#  'TLMUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AXLUSDT': Timestamp('2024-06-12 20:31:00'),
#  'SUPERUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000PEPEUSDC': Timestamp('2024-06-12 20:31:00'),
#  'DYDXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'OMUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ANCUSDT': Timestamp('2022-05-13 06:40:00'),
#  'GALAUSDT': Timestamp('2024-06-12 20:32:00'),
#  'DASHUSDT': Timestamp('2024-06-12 20:32:00'),
#  'MAVIAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'NEOUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BNBUSDC': Timestamp('2024-06-12 20:32:00'),
#  '1000FLOKIUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TRBUSDT': Timestamp('2024-06-12 20:34:00'),
#  'GMXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'SOLUSDT': Timestamp('2024-06-12 20:34:00'),
#  'BTSUSDT': Timestamp('2024-05-28 07:09:00'),
#  'DOGEUSDT': Timestamp('2024-06-12 20:32:00'),
#  'HIGHUSDT': Timestamp('2024-06-12 20:32:00'),
#  'GRTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'XEMUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000LUNCBUSD': Timestamp('2023-12-19 09:26:00'),
#  'YFIUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AIUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ILVUSDT': Timestamp('2024-06-12 20:32:00'),
#  'WIFUSDC': Timestamp('2024-06-12 20:34:00'),
#  'BOMEUSDT': Timestamp('2024-06-12 20:32:00'),
#  'NOTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'AGIXBUSD': Timestamp('2023-12-19 09:30:00'),
#  'KEYUSDT': Timestamp('2024-06-12 20:33:00'),
#  'METISUSDT': Timestamp('2024-06-12 20:33:00'),
#  'MTLUSDT': Timestamp('2024-06-12 20:33:00'),
#  'UNFIUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000SHIBUSDC': Timestamp('2024-06-12 20:31:00'),
#  'OPUSDT': Timestamp('2024-06-12 20:33:00'),
#  'FLMUSDT': Timestamp('2024-06-12 20:32:00'),
#  'STEEMUSDT': Timestamp('2024-06-12 20:33:00'),
#  'SFPUSDT': Timestamp('2024-06-12 20:33:00'),
#  'AGIXUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ADABUSD': Timestamp('2023-12-19 09:30:00'),
#  'LINKUSDT': Timestamp('2024-06-12 20:33:00'),
#  'PHBUSDT': Timestamp('2024-06-12 20:33:00'),
#  'VANRYUSDT': Timestamp('2024-06-12 20:34:00'),
#  'NEARUSDC': Timestamp('2024-06-12 20:33:00'),
#  'DODOXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'LTCUSDC': Timestamp('2024-06-12 20:33:00'),
#  'UNIBUSD': Timestamp('2023-12-19 09:50:00'),
#  'SNTUSDT': Timestamp('2024-06-12 09:13:00'),
#  'BSVUSDT': Timestamp('2024-06-12 20:32:00'),
#  'AAVEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'OGNUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ZENUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AKROUSDT': Timestamp('2022-05-27 09:16:00'),
#  'DOTBUSD': Timestamp('2023-12-19 09:38:00'),
#  'APTUSDT': Timestamp('2024-06-12 20:31:00'),
#  'BLZUSDT': Timestamp('2024-06-12 20:32:00'),
#  'APEBUSD': Timestamp('2023-12-19 09:33:00'),
#  'CAKEUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ONTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BNXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'LUNAUSDT': Timestamp('2022-05-13 06:49:00'),
#  'MASKUSDT': Timestamp('2024-06-12 20:33:00'),
#  'FILUSDT': Timestamp('2024-06-12 20:32:00'),
#  'PERPUSDT': Timestamp('2024-06-12 20:33:00'),
#  'CELRUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ICXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'IOTXUSDT': Timestamp('2024-06-12 20:33:00'),
#  'TAOUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AVAXUSDT': Timestamp('2024-06-12 20:31:00'),
#  'SKLUSDT': Timestamp('2024-06-12 20:33:00'),
#  'HOOKUSDT': Timestamp('2024-06-12 20:32:00'),
#  'FLOWUSDT': Timestamp('2024-06-12 20:32:00'),
#  'FRONTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'CVCUSDT': Timestamp('2024-06-11 23:34:00'),
#  'POLYXUSDT': Timestamp('2024-06-12 20:33:00'),
#  'CKBUSDT': Timestamp('2024-06-12 20:32:00'),
#  'FETUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ONDOUSDT': Timestamp('2024-06-12 20:33:00'),
#  'VETUSDT': Timestamp('2024-06-12 20:34:00'),
#  'MANAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LPTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'FTTUSDT': Timestamp('2024-06-12 03:19:00'),
#  'SOLUSDC': Timestamp('2024-06-12 20:33:00'),
#  'CTKUSDT': Timestamp('2024-06-11 23:34:00'),
#  'WAXPUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000PEPEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ETHWUSDT': Timestamp('2024-06-12 20:32:00'),
#  'HFTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'SAGAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'UNIUSDT': Timestamp('2024-06-12 20:34:00'),
#  'TRXBUSD': Timestamp('2023-12-19 09:49:00'),
#  'COTIUSDT': Timestamp('2024-06-12 20:32:00'),
#  'MEMEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'TURBOUSDT': Timestamp('2024-06-12 20:34:00'),
#  'LQTYUSDT': Timestamp('2024-06-12 20:33:00'),
#  'WLDUSDT': Timestamp('2024-06-12 20:34:00'),
#  'BCHUSDC': Timestamp('2024-06-12 20:31:00'),
#  'AXSUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ARKMUSDT': Timestamp('2024-06-12 20:31:00'),
#  '1000RATSUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ANKRUSDT': Timestamp('2024-06-12 20:31:00'),
#  'NKNUSDT': Timestamp('2024-06-12 20:33:00'),
#  'STGUSDT': Timestamp('2024-06-12 20:33:00'),
#  'MDTUSDT': Timestamp('2024-06-12 07:12:00'),
#  'ENJUSDT': Timestamp('2024-06-12 20:32:00'),
#  'GLMRUSDT': Timestamp('2024-06-12 03:43:00'),
#  'BALUSDT': Timestamp('2024-06-12 20:31:00'),
#  'SPELLUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LUNA2BUSD': Timestamp('2023-03-22 09:34:00'),
#  'ASTRUSDT': Timestamp('2024-06-12 20:31:00'),
#  'MAVUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ALICEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'MATICBUSD': Timestamp('2023-12-19 09:46:00'),
#  'KAVAUSDT': Timestamp('2024-06-12 20:32:00'),
#  'NFPUSDT': Timestamp('2024-06-12 20:33:00'),
#  'XRPUSDC': Timestamp('2024-06-12 20:34:00'),
#  'GMTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ENAUSDT': Timestamp('2024-06-12 20:32:00'),
#  'APTBUSD': Timestamp('2023-12-19 09:33:00'),
#  'MKRUSDT': Timestamp('2024-06-12 20:33:00'),
#  '1000SHIBUSDT': Timestamp('2024-06-12 20:31:00'),
#  'RENUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BOMEUSDC': Timestamp('2024-06-12 20:32:00'),
#  'AVAXBUSD': Timestamp('2023-12-19 09:35:00'),
#  'QNTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BLURUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BCHUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ATOMUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TOKENUSDT': Timestamp('2024-06-12 20:34:00'),
#  'DOGEBUSD': Timestamp('2023-12-19 09:38:00'),
#  'ICPUSDT': Timestamp('2024-06-12 20:32:00'),
#  'CVXBUSD': Timestamp('2023-12-19 09:37:00'),
#  'MATICUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BAKEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ZETAUSDT': Timestamp('2024-06-12 20:34:00'),
#  'LRCUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LOOMUSDT': Timestamp('2024-06-12 20:33:00'),
#  'OXTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'TOMOUSDT': Timestamp('2024-05-28 07:14:00'),
#  'ACHUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TWTUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ENSUSDT': Timestamp('2024-06-12 20:32:00'),
#  'EDUUSDT': Timestamp('2024-06-12 20:32:00'),
#  'MAGICUSDT': Timestamp('2024-06-12 20:33:00'),
#  'C98USDT': Timestamp('2024-06-12 20:32:00'),
#  'AUDIOUSDT': Timestamp('2024-05-28 07:17:00'),
#  'AEVOUSDT': Timestamp('2024-06-12 20:31:00'),
#  'SLPUSDT': Timestamp('2024-06-12 09:13:00'),
#  'ENAUSDC': Timestamp('2024-06-12 20:32:00'),
#  '1000BONKUSDT': Timestamp('2024-06-12 20:31:00'),
#  'FOOTBALLUSDT': Timestamp('2024-05-28 07:07:00'),
#  'GMTBUSD': Timestamp('2023-12-19 09:43:00'),
#  'STMXUSDT': Timestamp('2024-06-12 20:33:00'),
#  'UMAUSDT': Timestamp('2024-06-12 20:34:00'),
#  'TNSRUSDT': Timestamp('2024-06-12 20:34:00'),
#  'CFXUSDT': Timestamp('2024-06-12 20:32:00'),
#  'CRVUSDT': Timestamp('2024-06-12 20:32:00'),
#  'SCUSDT': Timestamp('2024-06-12 09:13:00'),
#  'BZRXUSDT': Timestamp('2021-12-19 02:10:00'),
#  'GALBUSD': Timestamp('2023-12-19 09:43:00'),
#  'RVNUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LUNA2USDT': Timestamp('2024-06-12 20:33:00'),
#  'PORTALUSDT': Timestamp('2024-06-12 20:33:00'),
#  'KNCUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BNBBUSD': Timestamp('2023-12-19 09:35:00'),
#  'WLDUSDC': Timestamp('2024-06-12 20:34:00'),
#  'EOSUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BBUSDT': Timestamp('2024-06-12 20:31:00'),
#  'MYROUSDT': Timestamp('2024-06-12 20:33:00'),
#  '1000BONKUSDC': Timestamp('2024-06-12 20:31:00'),
#  'TUSDT': Timestamp('2024-06-12 20:34:00'),
#  'FTTBUSD': Timestamp('2023-12-19 09:41:00'),
#  'GALUSDT': Timestamp('2024-06-12 20:32:00'),
#  'IDEXUSDT': Timestamp('2024-06-12 04:32:00'),
#  'RNDRUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ADAUSDT': Timestamp('2024-06-12 20:31:00'),
#  'POWRUSDT': Timestamp('2024-06-12 20:33:00'),
#  'REZUSDT': Timestamp('2024-06-12 20:33:00'),
#  'RAYUSDT': Timestamp('2024-06-12 08:06:00'),
#  'REEFUSDT': Timestamp('2024-06-12 20:33:00'),
#  'XAIUSDT': Timestamp('2024-06-12 20:34:00'),
#  'EGLDUSDT': Timestamp('2024-06-12 20:32:00'),
#  'IDUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BTCUSDT': Timestamp('2024-06-12 20:32:00'),
#  'LTCBUSD': Timestamp('2023-12-19 09:45:00'),
#  'TRXUSDT': Timestamp('2024-06-12 20:34:00'),
#  '1000LUNCUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TLMBUSD': Timestamp('2023-12-19 09:48:00'),
#  'SANDBUSD': Timestamp('2023-12-19 09:48:00'),
#  'ETHBTC': Timestamp('2024-06-12 20:32:00'),
#  'PHBBUSD': Timestamp('2023-12-19 09:47:00'),
#  'ETCBUSD': Timestamp('2023-12-19 09:39:00'),
#  'GASUSDT': Timestamp('2024-06-12 20:32:00'),
#  'AMBUSDT': Timestamp('2024-06-12 20:31:00'),
#  'CHZUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ETHFIUSDT': Timestamp('2024-06-12 20:32:00'),
#  'DARUSDT': Timestamp('2024-06-12 20:32:00'),
#  'HNTUSDT': Timestamp('2024-05-28 07:11:00'),
#  'XRPUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ZECUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ZILUSDT': Timestamp('2024-06-12 20:34:00'),
#  'SXPUSDT': Timestamp('2024-06-12 20:34:00'),
#  'KASUSDT': Timestamp('2024-06-12 20:33:00'),
#  'CHRUSDT': Timestamp('2024-06-12 20:32:00'),
#  'STXUSDT': Timestamp('2024-06-12 20:34:00'),
#  'ORBSUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LSKUSDT': Timestamp('2024-06-12 20:33:00'),
#  'DEFIUSDT': Timestamp('2024-06-12 20:32:00'),
#  'JUPUSDT': Timestamp('2024-06-12 20:33:00'),
#  'CTSIUSDT': Timestamp('2024-06-12 20:32:00'),
#  'WOOUSDT': Timestamp('2024-06-12 20:34:00'),
#  'GALABUSD': Timestamp('2023-12-19 09:42:00'),
#  'SUIUSDC': Timestamp('2024-06-12 20:34:00'),
#  'ATAUSDT': Timestamp('2024-06-12 20:31:00'),
#  'SNXUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BTCBUSD': Timestamp('2023-12-19 09:36:00'),
#  'LDOUSDT': Timestamp('2024-06-12 20:33:00'),
#  'DENTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'MANTAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ORDIUSDC': Timestamp('2024-06-12 20:33:00'),
#  'MBLUSDT': Timestamp('2024-05-28 07:18:00'),
#  'BANDUSDT': Timestamp('2024-06-12 20:32:00'),
#  'JTOUSDT': Timestamp('2024-06-12 20:32:00'),
#  'OMNIUSDT': Timestamp('2024-06-12 20:33:00'),
#  'STRKUSDT': Timestamp('2024-06-12 20:34:00'),
#  'BEAMXUSDT': Timestamp('2024-06-12 20:31:00'),
#  'WUSDT': Timestamp('2024-06-12 20:34:00'),
#  'LINKBUSD': Timestamp('2023-12-19 09:45:00'),
#  'SOLBUSD': Timestamp('2023-12-19 09:48:00'),
#  'KSMUSDT': Timestamp('2024-06-12 20:33:00'),
#  'XMRUSDT': Timestamp('2024-06-12 20:34:00'),
#  'NMRUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LDOBUSD': Timestamp('2023-12-19 09:44:00'),
#  'DYMUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BIGTIMEUSDT': Timestamp('2024-06-12 20:32:00'),
#  'WAVESBUSD': Timestamp('2023-12-19 09:50:00'),
#  'OMGUSDT': Timestamp('2024-06-12 20:33:00'),
#  'FTMBUSD': Timestamp('2023-12-19 09:41:00'),
#  'ETHBUSD': Timestamp('2023-12-19 09:40:00'),
#  'RSRUSDT': Timestamp('2024-06-12 20:33:00'),
#  'PENDLEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'STRAXUSDT': Timestamp('2024-06-12 09:37:00'),
#  'RDNTUSDT': Timestamp('2024-06-12 20:33:00'),
#  'NEARUSDT': Timestamp('2024-06-12 20:33:00'),
#  'FXSUSDT': Timestamp('2024-06-12 20:32:00'),
#  'MATICUSDC': Timestamp('2024-06-12 20:33:00'),
#  'JASMYUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ALGOUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TRUUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AUCTIONBUSD': Timestamp('2023-12-19 09:34:00'),
#  '1000SHIBBUSD': Timestamp('2023-12-19 09:29:00'),
#  'ARBUSDT': Timestamp('2024-06-12 20:31:00'),
#  'LINKUSDC': Timestamp('2024-06-12 20:33:00'),
#  'BNBUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ONGUSDT': Timestamp('2024-06-12 20:33:00'),
#  'OCEANUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ZRXUSDT': Timestamp('2024-06-12 20:34:00'),
#  'XLMUSDT': Timestamp('2024-06-12 20:34:00'),
#  'CELOUSDT': Timestamp('2024-06-12 20:32:00'),
#  'ARBUSDC': Timestamp('2024-06-12 20:31:00'),
#  'IOUSDT': Timestamp('2024-06-12 20:32:00'),
#  'DOTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'YGGUSDT': Timestamp('2024-06-12 20:34:00'),
#  'HIFIUSDT': Timestamp('2024-06-12 20:32:00'),
#  'CVXUSDT': Timestamp('2024-06-11 23:36:00'),
#  'RLCUSDT': Timestamp('2024-06-12 20:33:00'),
#  'HOTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'SEIUSDT': Timestamp('2024-06-12 20:33:00'),
#  'ONEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'USTCUSDT': Timestamp('2024-06-12 20:34:00'),
#  'AVAXUSDC': Timestamp('2024-06-12 20:31:00'),
#  'SUSHIUSDT': Timestamp('2024-06-12 20:34:00'),
#  'LEVERUSDT': Timestamp('2024-06-12 20:33:00'),
#  'BICOUSDT': Timestamp('2024-06-12 20:32:00'),
#  'XVSUSDT': Timestamp('2024-06-12 20:34:00'),
#  'XTZUSDT': Timestamp('2024-06-12 20:34:00'),
#  'BNTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'SRMUSDT': Timestamp('2024-05-28 07:10:00'),
#  'KLAYUSDT': Timestamp('2024-06-12 20:32:00'),
#  'JOEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'RADUSDT': Timestamp('2024-06-12 08:06:00'),
#  'SUIUSDT': Timestamp('2024-06-12 20:34:00'),
#  'XRPBUSD': Timestamp('2023-12-19 09:50:00'),
#  'AGLDUSDT': Timestamp('2024-06-12 20:31:00'),
#  'COMBOUSDT': Timestamp('2024-06-12 20:32:00'),
#  'API3USDT': Timestamp('2024-06-12 20:31:00'),
#  'DOGEUSDC': Timestamp('2024-06-12 20:32:00'),
#  'BTCUSDC': Timestamp('2024-06-12 20:32:00'),
#  'SSVUSDT': Timestamp('2024-06-12 20:33:00'),
#  'INJUSDT': Timestamp('2024-06-12 20:32:00'),
#  'GTCUSDT': Timestamp('2024-06-12 20:32:00'),
#  'NEARBUSD': Timestamp('2023-12-19 09:46:00'),
#  'PEOPLEUSDT': Timestamp('2024-06-12 20:33:00'),
#  'RONINUSDT': Timestamp('2024-06-12 20:33:00'),
#  '1000BTTCUSDT': Timestamp('2022-04-11 09:00:00'),
#  'STPTUSDT': Timestamp('2024-06-12 09:37:00'),
#  'SANDUSDT': Timestamp('2024-06-12 20:33:00'),
#  'IOSTUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BONDUSDT': Timestamp('2024-06-12 20:32:00'),
#  'COCOSUSDT': Timestamp('2024-05-28 07:16:00'),
#  'LINAUSDT': Timestamp('2024-06-12 20:33:00'),
#  'QTUMUSDT': Timestamp('2024-06-12 20:33:00'),
#  '1INCHUSDT': Timestamp('2024-06-12 20:31:00'),
#  'ETCUSDT': Timestamp('2024-06-12 20:32:00'),
#  'BADGERUSDT': Timestamp('2024-06-12 20:31:00'),
#  'BATUSDT': Timestamp('2024-06-12 20:31:00'),
#  'FILBUSD': Timestamp('2023-12-19 09:40:00'),
#  'AUCTIONUSDT': Timestamp('2024-06-12 20:31:00'),
#  'TONUSDT': Timestamp('2024-06-12 20:34:00'),
#  'DODOUSDT': Timestamp('2022-05-27 09:17:00'),
#  'APEUSDT': Timestamp('2024-06-12 20:31:00'),
#  'GLMUSDT': Timestamp('2024-06-12 20:32:00'),
#  'FILUSDC': Timestamp('2024-06-12 20:32:00'),
#  'KEEPUSDT': Timestamp('2022-02-15 02:03:00'),
#  'ORDIUSDT': Timestamp('2024-06-12 20:33:00'),
#  'LTCUSDT': Timestamp('2024-06-12 20:33:00'),
#  'XVGUSDT': Timestamp('2024-06-12 20:34:00'),
#  'TIAUSDC': Timestamp('2024-06-12 20:34:00'),
#  'ANTUSDT': Timestamp('2024-05-28 07:08:00'),
#  'PYTHUSDT': Timestamp('2024-06-12 20:33:00')}

# %%
lib_ohlc_1m.tail('binance_BTCUSDT').data
# Out:
#                     exchange   symbol     open     high      low    close  \
# datetime
# 2024-06-12 20:28:00  binance  BTCUSDT  67907.6  67932.0  67885.6  67885.6
# 2024-06-12 20:29:00  binance  BTCUSDT  67885.6  67949.6  67882.5  67941.1
# 2024-06-12 20:30:00  binance  BTCUSDT  67941.2  67941.2  67890.4  67937.7
# 2024-06-12 20:31:00  binance  BTCUSDT  67937.8  68022.1  67931.2  68017.0
# 2024-06-12 20:32:00  binance  BTCUSDT  68016.9  68022.5  67982.4  67994.7
#
#                      base_volume  quote_volume  base_buy_volume  \
# datetime
# 2024-06-12 20:28:00      259.329  1.761203e+07          135.397
# 2024-06-12 20:29:00      167.231  1.135912e+07           88.757
# 2024-06-12 20:30:00      183.672  1.247305e+07           58.497
# 2024-06-12 20:31:00      342.470  2.328403e+07          247.400
# 2024-06-12 20:32:00       97.896  6.656807e+06           34.930
#
#                      quote_buy_volume
# datetime
# 2024-06-12 20:28:00      9.195219e+06
# 2024-06-12 20:29:00      6.028229e+06
# 2024-06-12 20:30:00      3.972918e+06
# 2024-06-12 20:31:00      1.681967e+07
# 2024-06-12 20:32:00      2.375071e+06

# %%
q = adb.QueryBuilder()
q = q[q.index >= pd.to_datetime('6/1/2024')]

lib_ohlc_1m.read_batch(symbols=symbols[:])#, query_builder=q)
# Out:
# [VersionedItem(symbol='BTCUSDT', library='ohlc_1m', data=<class 'pandas.core.frame.DataFrame'>, version=0, metadata={'last_datetime': Timestamp('2024-06-08 19:18:00')}, host='LMDB(path=//home/quantfiction/arctic_demo)', timestamp=1718044451970394066),
#  VersionedItem(symbol='SOLUSDT', library='ohlc_1m', data=<class 'pandas.core.frame.DataFrame'>, version=0, metadata={'last_datetime': Timestamp('2024-06-09 06:18:00')}, host='LMDB(path=//home/quantfiction/arctic_demo)', timestamp=1718044458210463834)]

# %%
import ccxt

# %%
bnf_client = ccxt.binanceusdm(config={
    'enableRateLimit':True,
})

# %%
list_ohlc_data = bnf_client.fapipublic_get_klines(params={
    'interval':'1m',
    'symbol':'BTCUSDT',
    'startTime':0,
    'limit':1500,
})

df_ohlc_data = (
    pd.DataFrame(
        data=list_ohlc_data,
        columns=[
            'start_time',
            'open',
            'high',
            'low',
            'close',
            'base_volume',
            'end_time',
            'quote_volume',
            'num_trades',
            'base_buy_volume',
            'quote_buy_volume',
            'ignore',
        ],
    )
    .astype({
        'start_time':np.int64,
        'open':np.float64,
        'high':np.float64,
        'low':np.float64,
        'close':np.float64,
        'quote_volume':np.float64,
        'base_volume':np.float64,
        'num_trades':np.int64,
        'base_buy_volume':np.float64,
        'quote_buy_volume':np.float64,
    })        
    .assign(datetime = lambda x: pd.to_datetime(x['start_time'], unit='ms'))
    .drop(['start_time','end_time','ignore'], axis='columns')
    .set_index('datetime')
    .sort_index()
)

display(df_ohlc_data.head())
# Out:
#                         open     high      low    close  base_volume  \
# datetime
# 2019-09-08 17:57:00  10000.0  10000.0  10000.0  10000.0        0.001
# 2019-09-08 17:58:00  10000.0  10000.0  10000.0  10000.0        0.000
# 2019-09-08 17:59:00  10000.0  10000.0  10000.0  10000.0        0.001
# 2019-09-08 18:00:00  10000.0  10000.0  10000.0  10000.0        0.000
# 2019-09-08 18:01:00  10000.0  10000.0  10000.0  10000.0        0.000
#
#                      quote_volume  num_trades  base_buy_volume  \
# datetime
# 2019-09-08 17:57:00          10.0           1            0.000
# 2019-09-08 17:58:00           0.0           0            0.000
# 2019-09-08 17:59:00          10.0           1            0.001
# 2019-09-08 18:00:00           0.0           0            0.000
# 2019-09-08 18:01:00           0.0           0            0.000
#
#                      quote_buy_volume
# datetime
# 2019-09-08 17:57:00               0.0
# 2019-09-08 17:58:00               0.0
# 2019-09-08 17:59:00              10.0
# 2019-09-08 18:00:00               0.0
# 2019-09-08 18:01:00               0.0

# %%
(
    df_ohlc_data
    .resample('D')
    .agg({
        'open':'first',
        'high':'max',
        'low':'min',
        'close':'last',
        'quote_volume':'sum',
        'base_volume':'sum',
        'num_trades':'sum',
        'quote_buy_volume':'sum',
        'base_buy_volume':'sum',
    })
)
# Out:
#                 open      high       low     close  quote_volume  base_volume  \
# datetime
# 2019-09-08  10000.00  10412.65  10000.00  10391.63  3.209630e+07     3096.291
# 2019-09-09  10391.63  10475.54  10077.22  10261.32  1.256119e+08    12215.285
#
#             num_trades  quote_buy_volume  base_buy_volume
# datetime
# 2019-09-08        3754      4.033562e+02            0.039
# 2019-09-09        9604      3.835383e+07         3718.024
